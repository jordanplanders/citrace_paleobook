# %% [markdown]
# # `Kerchunk` tutorial
#
# Created July 2021 by [Lucas Sterzinger](mailto:lsterzinger@ucdavis.edu) ([Twitter](https://twitter.com/lucassterzinger)) as part of the NCAR [Summer Internship in Parallel Computational Science (SIParCS)](https://www2.cisl.ucar.edu/siparcs)
#
# If any part of this tutorial is now out of date, please feel free to open a pull request with a fix

# %% [markdown]
# ### Import Kerchunk

# %%
from kerchunk.hdf import SingleHdf5ToZarr 
from kerchunk.combine import MultiZarrToZarr

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import fsspec
import ujson
from tqdm import tqdm
from glob import glob
import os

# %% [markdown]
# ### Dask makes some of the processing faster, but it is not required to run this tutorial.
# This code block starts 8 local dask workers

# %%
import dask
from dask.distributed import Client

client = Client(n_workers=8)
client
# Out:
# <Client: 'tcp://127.0.0.1:54665' processes=8 threads=8, memory=16.00 GiB>

# %% [markdown]
# ## Create metadata JSONs
#
# ### Get a list of S3 files for the 210th day of 2020 (July 28, 2020) and prepend `s3://` to each url

# %%
variables = [
    # 'MOC',
    # # 'grid',
    # 'd18O',
    # 'CISO_DIC_d13C',
    # 'ABIO_D14Cocn',
    'ABIO_D14Catm',
    # 'ND143',
    # 'ND144',
    # # 'PD',
    # 'SALT',
    # 'TEMP',
    # 'IAGE',
]
# variables = ['IAGE', 'ABIO_D14Catm']

url_d = {'IAGE': 'https://figshare.com/ndownloader/files/38534591',
         'd18O': 'https://figshare.com/ndownloader/files/38530430',
         'ABIO_D14Cocn':'https://figshare.com/ndownloader/files/38231892',
        'ABIO_D14Catm':'s3://citrace/ctrace.decadal.ABIO_D14Catm.nc',#'https://figshare.com/ndownloader/files/38231991',
        'CISO_DIC_d13C': 'https://figshare.com/ndownloader/files/38526806',
        'ND143': 'https://figshare.com/ndownloader/files/38232651',
        'ND144':'https://figshare.com/ndownloader/files/38232060',
        'SALT': 'https://figshare.com/ndownloader/files/38541851',
         # 'grid':'https://gdex.ucar.edu/dataset/204_ajahn/file/ctrace.grid.nc',
         # 'MOC':'https://gdex.ucar.edu/dataset/204_ajahn/file/ctrace.decadal.MOC.nc'
        'TEMP': 'https://figshare.com/ndownloader/files/38543534'
        # 'PD':
}

# %%
fs = fsspec.filesystem('s3', anon=True)
# s3://citrace/ctrace.decadal.ABIO_D14Catm.nc
# s3://citrace/ctrace.decadal.ABIO_D14Catm.nc
# url = 'https://citrace.s3.us-west-1.amazonaws.com/ctrace.decadal.ABIO_D14Catm.nc?response-content-disposition=inline&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEDkaCXVzLXdlc3QtMSJGMEQCIEIlRc1kXMzxL27bji4KAgQ9Ub5VEi3K5aDd95pOjjTNAiAHMzSBjMuMZtg%2FrC8oW%2F6vDMcxqDX3gvQVJ9ccYSdZlyrtAgiS%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAQaDDUxNzMyMDYxNDE5MSIMYp%2FEWPEII2OMlE8tKsECjMwwvl9rgowfrKQ4azfMpLLogzSJ0DujQVDiRwVwginGWzmcpoHljeY6Q7RBauuIJWKPk6fgibZKCdPs%2BldcTV348JXMRQ16zNJM4eWnA1nMp6pT1ZII32vQPbdc8w4%2F7%2B5Pv9WG7XvToiV1uD%2FYnKqaMMRoJKoLuIpO6jVpZ2iz72TLejqqQjkSw5Jk97tZqu9ES%2BSX9SPwACKd%2BXH2bveoq0jpk%2Botk1V50IkgpANXwlfk3dyO5Cz7vabcE%2FFgpwZAeRJ%2FTE41ioY%2F2WJaMI%2BDMeCDIVPlGWAgDnsDl2LQkAmtGFAGYhootJm%2F%2BQIwDxf6WFgJX%2BiI%2BXYIoNpFqjIjpfExrW0RMMEbMLk9UmVDRSumYH6%2FnxaYcISS2mRj8vG6NcOCcz2v8UAOR7jrLijCsKLzJYc2mdM7JZOM%2F%2FVRMI6VwqQGOrQCe2cD8LUEGUFuCi61Ry7xDfmjweOACSFzmNFfzTOIlQuRZWNEnrb8Vj23w8eGbDfUwZThgYhQIOgmJI4zUJXQ59nsvfTawlynQPSQGgBo%2FFgfxpj7HgS2LGcZvL7pALYsD79fQmAQM2PXBBen2D4PxTtwsyLS4brzcyPv7JH951Zwqy%2FaJd3R0TmhAfGO6XFLO9u0Yvv7p4Idzec5i50e3%2BemjuorPl6aKO1vd53zWFXlJcCIhgq438OSJA2z%2BZGZp%2BsxDAeu1Lx2RRu9N3zHWcM%2B1YfcTXL9IOEe4SUfpo2MxnivVHICKf3uFlLg3yydFDLngCmbfzu4ow1MyA%2BM%2BxBo1BGqZD5u7fUZw6SSQg2GWwbQMpYr3B40EmX8PkYPOnJLCH3IHsuy%2BklG1Vntku2HMuc%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230619T174553Z&X-Amz-SignedHeaders=host&X-Amz-Expires=7200&X-Amz-Credential=ASIAXQ4VWEEXVA2UGYHK%2F20230619%2Fus-west-1%2Fs3%2Faws4_request&X-Amz-Signature=36ace8592dc0bafbc05cf757c0f09067d82e24bb91787c9292cd4af13bf7fdc9'
urls = ['s3://' + f for f in fs.glob("s3://citrace/ctrace.decadal.ABIO_D14Catm.nc")]
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/opt/miniconda3/envs/paleobook-dev/lib/python3.10/site-packages/s3fs/core.py:113, in _error_wrapper(func, args, kwargs, retries)
#     112 try:
# --> 113     return await func(*args, **kwargs)
#     114 except S3_RETRYABLE_ERRORS as e:
#
# File ~/opt/miniconda3/envs/paleobook-dev/lib/python3.10/site-packages/aiobotocore/client.py:371, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     370     error_class = self.exceptions.from_code(error_code)
# --> 371     raise error_class(parsed_response, operation_name)
#     372 else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[39], line 5
# ...

# %%
urls

# %% [markdown]
# ## Create Reference JSONS
# ### This function creates JSON metadata files for each of the S3 files in the local `jsons/` directory
#
# These files point to the S3 location of the netCDF files, and only need to be created once. Tihs process took me about 10 minutes to generate the JSONs for 24 files. This function could easily be made to run in parallel for faster performance

# %%
def gen_json(var):
    u = url_d[var]
    so = dict(
        mode="rb",
    )#anon=True, default_fill_cache=False,  default_cache_type="none"
    with fsspec.open(u, **so) as inf:
        
        h5chunks = SingleHdf5ToZarr(inf, u, inline_threshold=300)
        with open("jsons/{}.json".format(var), 'wb') as outf:
            outf.write(ujson.dumps(h5chunks.translate()).encode())

# %%
# Create json/ folder if it doesn't already exist
import pathlib
pathlib.Path('./jsons/').mkdir(exist_ok=True)

# %% [markdown]
# Run the `gen_json()` function defined above with dask. This function can be run in parallel with each worker creating a single file. If you do not want to use dask, replace the uncommented line with the commented block below it.

# %%
dask.compute(*[dask.delayed(gen_json)(var) for var in variables]);

# If not using dask, use
# for u in tqdm(urls):
#     gen_json(u)
# Out:
# 2023-06-19 11:02:14,378 - distributed.worker - WARNING - Compute Failed
# Key:       gen_json-2e32dc25-9963-4028-9306-c98c4d726751
# Function:  gen_json
# args:      ('ABIO_D14Catm')
# kwargs:    {}
# Exception: "PermissionError('Forbidden')"
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/opt/miniconda3/envs/paleobook-dev/lib/python3.10/site-packages/s3fs/core.py:113, in _error_wrapper()
#     112 try:
# --> 113     return await func(*args, **kwargs)
#     114 except S3_RETRYABLE_ERRORS as e:
#
# File ~/opt/miniconda3/envs/paleobook-dev/lib/python3.10/site-packages/aiobotocore/client.py:371, in _make_api_call()
#     370     error_class = self.exceptions.from_code(error_code)
# --> 371     raise error_class(parsed_response, operation_name)
#     372 else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# ...

# %% [markdown]
# ***
# ## Read remote netCDF files with xarray and fsspec
#
# ### First, create a list of JSON files

# %%
json_list = sorted(glob("./jsons/*.json"))

# %% [markdown]
# ### Then, loop over the files and use `fsspec.get_mapper()` to create mappers for each file object, creating a list of mappers

# %%
 fs = HTTPFileSystem()

from fsspec.implementations.http import HTTPFileSystem
m_list = []
for j in tqdm(json_list):
    with open(j) as f:
    with open("jsons/{}.json".format(var)) as f:
        fs = HTTPFileSystem()
        store = fs.get_mapper("https://thewtex.github.io/allen-ccf-itk-vtk-zarr/meshes/{0}.zarr".format(allen_id))

        m_list.append(fsspec.get_mapper("reference://", 
                        fo=ujson.load(f),
                        # remote_protocol='s3',
                        remote_options={'anon':True}))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 11.38it/s]

# %% [markdown]
# ### Now, the mapper list can be passed directly to xarray.open_mfdataset() as long as the engine is specified as "zarr"

# %%
# %%time
ds = xr.open_mfdataset(m_list, engine='zarr', 
                       combine='nested',consolidated=False, concat_dim='t', 
                        coords='minimal', use_cftime=True, data_vars='minimal', compat='override',
                        parallel=True)
ds
# Out:
# /Users/jlanders/opt/miniconda3/envs/paleobook-dev/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   return func(*args, **kwargs)
# /Users/jlanders/opt/miniconda3/envs/paleobook-dev/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# ...

# %%
tmp_dat = ds['SALT'].isel(z_t = 3, time=4)

# %%
bins =tmp_dat.compute().plot.hist()
# Out:
# 2023-06-19 02:11:00,205 - tornado.application - ERROR - Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 2 memory: 79 MB fds: 284>>
# Traceback (most recent call last):
#   File "/Users/jlanders/opt/miniconda3/envs/paleobook-dev/lib/python3.10/site-packages/tornado/ioloop.py", line 919, in _run
#     val = self.callback()
#   File "/Users/jlanders/opt/miniconda3/envs/paleobook-dev/lib/python3.10/site-packages/distributed/system_monitor.py", line 164, in update
#     net_ioc = psutil.net_io_counters()
#   File "/Users/jlanders/opt/miniconda3/envs/paleobook-dev/lib/python3.10/site-packages/psutil/__init__.py", line 2119, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
# OSError: [Errno 12] Cannot allocate memory
# ERROR:tornado.application:Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 2 memory: 79 MB fds: 284>>
# Traceback (most recent call last):
# ...

# %% [markdown]
# # One JSON, multiple data files

# %% [markdown]
# The 1-file, 1-JSON method above doesn't scale well for larger datasets.
# Instead, we can combine multiple JSONS into a single JSON describing the whole dataset.

# %%
mzz = MultiZarrToZarr(
    json_list,
    remote_protocol="s3",
    remote_options={'anon':True},
    concat_dims='t',
    inline_threshold=0
)

# %% [markdown]
# This part actually writes the metadata to a file

# %%
# %%time
mzz.translate("combined.json")

# %% [markdown]
# ## Now, use the `combined.json` file to open the multifile dataset

# %%
# %%time
fs = fsspec.filesystem("reference", fo="./combined.json", remote_protocol="s3", 
                        remote_options={"anon":True}, skip_instance_cache=True)
m = fs.get_mapper("")
ds = xr.open_dataset(m, engine='zarr')

ds

# %% [markdown]
# ### Take a subset of the data (in this case, the Gulf Stream)

# %% [markdown]
# ### Select a single time with `.isel(t=14)`

# %%
# %%time
subset = ds.sel(x=slice(-0.01,0.07215601),y=slice(0.12,0.09))  #reduce to GS region

masked = subset.SST.where(subset.DQF==0)

masked.isel(t=14).plot(vmin=14+273.15,vmax=30+273.15,cmap='inferno')

# %% [markdown]
# ### Plot a mean along the time axis (1-day average)

# %%
# %%time
subset = ds.sel(x=slice(-0.01,0.07215601),y=slice(0.12,0.09))  #reduce to GS region

masked = subset.SST.where(subset.DQF==0)

masked.mean("t", skipna=True).plot(vmin=14+273.15,vmax=30+273.15,cmap='inferno')

# %% [markdown]
# ### For details on how to plot GOES data on a lat/lon grid, see [this blog post I wrote](https://lsterzinger.medium.com/add-lat-lon-coordinates-to-goes-16-goes-17-l2-data-and-plot-with-cartopy-27f07879157f)
